# %%
from pathlib import Path 
import sys
import os
import pandas as pd

# %%
REPO_PATH = Path('/home','shawn','Soccer-Player-Attributes-Comparison')
sys.path.append(os.fspath(REPO_PATH))

# %%
from fifa_similarity_search.service.index import ExampleIndex

# %%
embeddings = pd.read_csv(Path(REPO_PATH, 'datasets','soccer_player_embeddings_v1.csv'))

# %%
embeddings
# Out:
#           id       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0      97455 -0.020058  0.683692 -0.255270 -0.329416 -0.594869  0.124635
# 1      42881  0.068503  0.188564 -0.228424 -0.542123 -0.304828  0.015172
# 2      97483  2.236177 -0.317256  1.209209  0.559709  0.488686  0.023748
# 3      97505 -0.553902  0.108279 -0.700631  1.268173  0.137731 -0.259513
# 4      42402  0.235236 -0.260011  1.173912 -0.533751  0.475334 -0.042503
# ...      ...       ...       ...       ...       ...       ...       ...
# 6353  153509 -0.025461 -0.231916 -0.528128 -0.564062  1.004626  0.639091
# 6354   95621  0.285636 -0.168007 -0.540073 -0.391587  0.996375  0.933036
# 6355   19676 -0.298870 -0.260222 -0.520168 -0.737590  1.051284  0.613741
# 6356   81812  0.105301 -0.597632 -0.138244 -0.930273  0.135653 -0.348811
# 6357   18846  0.699142  0.516312 -0.209653 -0.019365 -0.543188  0.182302
#
#            PC7       PC8       PC9  ...      PC11      PC12      PC13  \
# 0    -0.209664  0.304167 -0.082228  ...  0.203576  0.047019 -0.091479
# 1     0.001972 -0.151031 -0.113127  ...  0.235491 -0.188535  0.258280
# 2    -0.034294 -0.239571 -0.111753  ...  0.154176 -0.245468  0.054037
# 3     0.327372 -0.145581 -0.180327  ...  0.070879 -0.004284 -0.028598
# 4    -0.011437 -0.537734  0.061248  ... -0.264887  0.065391 -0.188249
# ...        ...       ...       ...  ...       ...       ...       ...
# 6353  0.287734  0.037770 -0.207479  ...  0.044857 -0.104830  0.296571
# 6354 -0.012724 -0.056702 -0.354121  ... -0.212309 -0.217510  0.164363
# 6355 -0.062358  0.262144 -0.146928  ... -0.154990 -0.362669 -0.112991
# 6356  0.387094 -0.476624  0.106154  ... -0.019854  0.143886 -0.055698
# 6357  0.340370 -0.097960 -0.197806  ...  0.088472  0.141994 -0.162300
#
#           PC14  player_fifa_api_id  player_api_id  overall_rating  potential  \
# 0     0.273118              119152          30831            78.0       78.0
# 1    -0.195703              199284         133126            63.0       63.0
# 2     0.010629              201169         206641            58.0       63.0
# 3    -0.068586              183559          11242            67.0       67.0
# 4     0.083385              225951         664962            64.0       75.0
# ...        ...                 ...            ...             ...        ...
# 6353  0.210710              172555          45400            68.0       70.0
# 6354 -0.001703              208127         307224            64.0       68.0
# 6355 -0.015201              166074         210065            72.0       75.0
# 6356  0.344106              228738         423024            67.0       79.0
# 6357  0.186084              208834         317932            66.0       76.0
#
#            player_name             birthday
# 0           Kolo Toure  1981-03-19 00:00:00
# 1       Dennis Hediger  1986-09-22 00:00:00
# 2        Konrad Forenc  1992-07-17 00:00:00
# 3     Konstantin Engel  1988-07-27 00:00:00
# 4        Denis Bouanga  1994-11-11 00:00:00
# ...                ...                  ...
# 6353   Ronnie Schwartz  1989-08-29 00:00:00
# 6354    Kevin Koubemba  1993-03-23 00:00:00
# 6355              Bebe  1990-07-12 00:00:00
# 6356      Jhon Murillo  1995-11-21 00:00:00
# 6357     Baptiste Aloe  1994-06-29 00:00:00
#
# [6358 rows x 21 columns]

# %%
columns = []
for i in range(1,15):
    columns.append(f'PC{i}')

# %%
def get_dataset(df):
    vectors = np.array(df[columns])
    labels = np.array(df['player_fifa_api_id'])
