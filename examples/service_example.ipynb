# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
from pprint import pprint

import sys
import os
import pandas as pd
import numpy as np

# %%
REPO_PATH = Path('/home','shawn','Soccer-Player-Attributes-Comparison')
sys.path.append(os.fspath(REPO_PATH))

# %%
from fifa_similarity_search.service.index import ExampleIndex

# %%
embeddings = pd.read_csv(Path(REPO_PATH, 'datasets','final_embeddings','dnn_embeddings_v3.csv'))

# %%
df = pd.read_csv(Path(REPO_PATH, 'datasets','cleaned_soccer_data_120K.csv'))

# %%
df = df.query('fifa==16')

# %%
embeddings = embeddings.merge(df[['sofifa_id','overall','potential']], how='left', on=['sofifa_id'])

# %%
embeddings = embeddings.rename(columns={"dob": "birthday", "short_name": "player_name","overall":"overall_rating","sofifa_id":"player_fifa_api_id"})

# %%
#embeddings.to_csv(Path(REPO_PATH, 'datasets','final_embeddings','dnn_embeddings_sh_v2.csv'), index=False)

# %%
embeddings = pd.read_csv(Path(REPO_PATH, 'datasets','final_embeddings','dnn_embeddings_sh_v2.csv'))

# %%
embeddings
# Out:
#        player_fifa_api_id        player_name  \
# 0                  158023           L. Messi
# 1                   20801  Cristiano Ronaldo
# 2                    9014          A. Robben
# 3                  167495           M. Neuer
# 4                  176580          L. Suárez
# ...                   ...                ...
# 14876              224867           R. Horne
# 14877              229852        C. Shephard
# 14878              227910           L. Gooch
# 14879              225339       S. Warburton
# 14880               11728      B. Richardson
#
#                                  long_name    birthday  fifa  \
# 0           Lionel Andrés Messi Cuccittini  1987-06-24    16
# 1      Cristiano Ronaldo dos Santos Aveiro  1985-02-05    16
# 2                             Arjen Robben  1984-01-23    16
# 3                             Manuel Neuer  1986-03-27    16
# 4                 Luis Alberto Suárez Díaz  1987-01-24    16
# ...                                    ...         ...   ...
# 14876                           Ryan Horne  1995-11-02    16
# 14877                       Corey Shephard  1997-12-28    16
# 14878                           Liam Gooch  1997-11-25    16
# 14879                        Sam Warburton  1996-10-10    16
# 14880                     Barry Richardson  1969-08-05    16
#
#       player_positions_general player_positions        PC0        PC1  \
# 0                          ATK           RW, CF  -2.820459   0.463528
# 1                          ATK           LW, LM  -6.879275  -0.027998
# 2                          MID       RM, LM, RW  -1.214763  -0.025625
# 3                           GK               GK -20.294119  13.371469
# 4                          ATK               ST  -5.768158   0.626190
# ...                        ...              ...        ...        ...
# 14876                      MID               CM   0.423741   0.607692
# 14877                      MID               CM   0.472541   0.962732
# 14878                       GK               GK  -6.923523   7.113905
# 14879                      DEF           LB, LM   0.109028  -0.682285
# 14880                       GK               GK -10.102876   6.951650
#
#              PC2  ...      PC24       PC25       PC26       PC27       PC28  \
# 0     -14.149214  ... -7.790683   1.493453  -1.563942  -0.325550  -1.689328
# 1     -14.428118  ... -8.056432   1.180157  -3.449321  -0.729221  -4.749788
# 2     -11.304901  ... -6.153422   1.276017  -1.281750   0.319182  -0.955590
# 3       4.543362  ...  1.984269  10.765091 -14.294777 -11.988588 -19.039328
# 4     -11.303053  ... -6.374952   1.721924  -2.405569  -1.052525  -3.861679
# ...          ...  ...       ...        ...        ...        ...        ...
# 14876   0.048621  ...  0.342504   0.010696  -2.454395  -0.168915  -3.610232
# 14877  -0.677146  ... -0.093138   0.293502  -2.360829  -0.814828  -3.576773
# 14878   2.510575  ...  1.565786   6.228837 -10.562727  -4.795074 -12.354741
# 14879   0.891646  ...  0.013958   0.833154   0.838275   0.634556   0.705203
# 14880   2.399386  ...  1.181535   5.969239 -11.093196  -4.961093 -14.070323
#
#             PC29      PC30       PC31  overall_rating  potential
# 0      -8.339558 -0.498441 -11.954984              94         95
# 1     -10.166391  1.064353 -11.029340              93         93
# 2      -6.504946 -0.260668  -8.885252              90         90
# 3      -8.704237 -7.056895  -0.351833              90         90
# 4      -8.001318 -0.152860  -8.865654              90         90
# ...          ...       ...        ...             ...        ...
# 14876   0.519966 -0.259955  -0.734067              44         57
# 14877   0.158617 -0.910374  -2.140381              44         56
# 14878  -4.431404 -4.144162   1.331121              44         54
# 14879   0.730203  0.028193   0.589721              44         51
# 14880  -5.110036 -3.012667   1.103752              44         44
#
# [14881 rows x 41 columns]

# %%
embeddings_columns = []
for i in range(0,32):
    embeddings_columns.append(f'PC{i}')

# %%
def get_dataset(df, embeddings_columns):
    vectors = np.ascontiguousarray(df[embeddings_columns])
    labels = np.ascontiguousarray(df['player_fifa_api_id'])
    
    return vectors.astype('float32'), np.expand_dims(labels, axis=1)

# %%
class Service_Index():
    def __init__(self, df, embeddings_columns):
        vectors, labels = get_dataset(df, embeddings_columns)
        self.df = df
        self.vectors = vectors
        self.labels = labels

        self.index = ExampleIndex(vectors, labels)
        self.index.build()

        self.columns = ['player_name', 'player_positions', 'overall_rating', 'potential', 'birthday',
                        'player_fifa_api_id']

    def search_by_player_name(self, player_name):
        # player_name must be exact
        query_id = self.df[self.df.player_name == player_name].player_fifa_api_id.values[0]
        id_ = self.df[self.df.player_fifa_api_id == query_id].index.values[0]
        results, distances = self.index.query(np.expand_dims(self.vectors[id_], axis=0), k=11)
        response = []
        for ind, result_id in enumerate(results):
            if query_id != result_id:
                result_dict = self.df[self.df.player_fifa_api_id == result_id[0]][self.columns].iloc[0].to_dict()
                result_dict["similarity_score"] = 1/(1+distances[ind])
                response.append(result_dict)
        return response

    def search_by_vector(self, vector, query_id):
        results, distances = self.index.query(np.expand_dims(vector, axis=0), k=11)
        response = []
        for ind, result_id in enumerate(results):
            if query_id != result_id:
                result_dict = self.df[self.df.player_fifa_api_id == result_id[0]][self.columns].iloc[0].to_dict()
                result_dict["similarity_score"] = 1/(1+distances[ind])
                response.append(result_dict)
        return response

# %% [markdown]
# ## Use Case 1: Search all in database

# %%
all_index = Service_Index(embeddings, embeddings_columns)

# %%
pprint(all_index.search_by_player_name('B. Richardson'))
# Out:
# [{'birthday': '1995-02-14',
#   'overall_rating': 46,
#   'player_fifa_api_id': 229393,
#   'player_name': 'S. Hornby',
#   'player_positions': 'GK',
#   'potential': 55,
#   'similarity_score': 0.10569022761313629},
#  {'birthday': '1997-06-22',
#   'overall_rating': 46,
#   'player_fifa_api_id': 228155,
#   'player_name': 'C. Johns',
#   'player_positions': 'GK',
#   'potential': 57,
#   'similarity_score': 0.10478651282969634},
#  {'birthday': '1997-07-06',
#   'overall_rating': 45,
#   'player_fifa_api_id': 215734,
#   'player_name': 'E. Farrell',
#   'player_positions': 'GK',
#   'potential': 61,
#   'similarity_score': 0.09459603923470901},
#  {'birthday': '1998-06-12',
#   'overall_rating': 46,
#   'player_fifa_api_id': 226099,
#   'player_name': 'A. Bishop',
#   'player_positions': 'GK',
#   'potential': 53,
#   'similarity_score': 0.08879549031204292},
#  {'birthday': '1997-08-02',
#   'overall_rating': 48,
#   'player_fifa_api_id': 225342,
#   'player_name': 'J. Stevens',
#   'player_positions': 'GK',
#   'potential': 54,
#   'similarity_score': 0.0842613598741531},
#  {'birthday': '1992-05-19',
#   'overall_rating': 50,
#   'player_fifa_api_id': 225851,
#   'player_name': 'S. Al Saleh',
#   'player_positions': 'GK',
#   'potential': 55,
#   'similarity_score': 0.07161115957689033},
#  {'birthday': '1996-01-27',
#   'overall_rating': 48,
#   'player_fifa_api_id': 225427,
#   'player_name': 'S. Arango',
#   'player_positions': 'GK',
#   'potential': 61,
#   'similarity_score': 0.06033091973445042},
#  {'birthday': '1993-11-19',
#   'overall_rating': 50,
#   'player_fifa_api_id': 210750,
#   'player_name': 'M. Al Barih',
#   'player_positions': 'GK',
#   'potential': 56,
#   'similarity_score': 0.055265931878937115},
#  {'birthday': '1998-07-29',
#   'overall_rating': 47,
#   'player_fifa_api_id': 227529,
#   'player_name': 'M. Hudson',
#   'player_positions': 'GK',
#   'potential': 65,
#   'similarity_score': 0.05475995310777941},
#  {'birthday': '1997-09-12',
#   'overall_rating': 46,
#   'player_fifa_api_id': 225331,
#   'player_name': 'D. Henry',
#   'player_positions': 'GK',
#   'potential': 58,
#   'similarity_score': 0.05416713718319687}]

# %%
#First Name is search query
#The rest are search results

# %% [markdown]
# ## Use Case 2: Filter-Search: only look at all the under-21s (youths)

# %% [markdown]
# Database is 2016. Those under 21 y-o would be born after 1995. Purpose of this is to get the potential next generation Cristiano Ronaldo

# %%
embeddings.birthday = pd.to_datetime(embeddings.birthday)
new_df = embeddings.query('birthday > 19950101')

# %%
player_name = 'Cristiano Ronaldo'
query_id = embeddings[embeddings.player_name == player_name].player_fifa_api_id.values[0]
query_vector = np.array(embeddings[embeddings.player_fifa_api_id == query_id][embeddings_columns])
query_vector = query_vector.reshape((32)).astype('float32')

# %%
index = Service_Index(new_df, embeddings_columns)
response = index.search_by_vector(query_vector, query_id)
pprint(response)
# Out:
# [{'birthday': Timestamp('1997-04-05 00:00:00'),
#   'overall_rating': 64,
#   'player_fifa_api_id': 228635,
#   'player_name': 'Borja Mayoral',
#   'player_positions': 'ST',
#   'potential': 79,
#   'similarity_score': 0.27580427548496017},
#  {'birthday': Timestamp('1996-06-12 00:00:00'),
#   'overall_rating': 68,
#   'player_fifa_api_id': 222059,
#   'player_name': 'Mosquito',
#   'player_positions': 'ST',
#   'potential': 83,
#   'similarity_score': 0.23187068767120578},
#  {'birthday': Timestamp('1997-01-08 00:00:00'),
#   'overall_rating': 62,
#   'player_fifa_api_id': 225019,
#   'player_name': 'R. Cisneros',
#   'player_positions': 'ST',
#   'potential': 73,
#   'similarity_score': 0.20609737694989047},
#  {'birthday': Timestamp('1995-07-15 00:00:00'),
#   'overall_rating': 70,
#   'player_fifa_api_id': 211239,
#   'player_name': 'C. Jean',
#   'player_positions': 'ST, LM, RM',
#   'potential': 82,
#   'similarity_score': 0.1940049148049897},
#  {'birthday': Timestamp('1995-06-11 00:00:00'),
#   'overall_rating': 61,
#   'player_fifa_api_id': 216390,
#   'player_name': 'O. Álvarez',
#   'player_positions': 'LM',
#   'potential': 71,
#   'similarity_score': 0.17361031374168012},
#  {'birthday': Timestamp('1995-09-15 00:00:00'),
#   'overall_rating': 72,
#   'player_fifa_api_id': 220883,
#   'player_name': 'R. Borré',
#   'player_positions': 'ST',
#   'potential': 81,
#   'similarity_score': 0.16988936200272484},
#  {'birthday': Timestamp('1995-02-13 00:00:00'),
#   'overall_rating': 67,
#   'player_fifa_api_id': 209264,
#   'player_name': 'B. Finne',
#   'player_positions': 'ST, LM, RM',
#   'potential': 78,
#   'similarity_score': 0.16052794480259747},
#  {'birthday': Timestamp('1996-07-12 00:00:00'),
#   'overall_rating': 66,
#   'player_fifa_api_id': 211591,
#   'player_name': 'M. Dembélé',
#   'player_positions': 'ST',
#   'potential': 81,
#   'similarity_score': 0.15722031244166515},
#  {'birthday': Timestamp('1997-03-28 00:00:00'),
#   'overall_rating': 63,
#   'player_fifa_api_id': 229217,
#   'player_name': 'Y. Yeboah',
#   'player_positions': 'ST, RM',
#   'potential': 76,
#   'similarity_score': 0.15472497066008917},
#  {'birthday': Timestamp('1995-04-20 00:00:00'),
#   'overall_rating': 68,
#   'player_fifa_api_id': 209287,
#   'player_name': 'J. Dongou Tsafack',
#   'player_positions': 'ST, RW, LW, CF',
#   'potential': 79,
#   'similarity_score': 0.14357038529458377},
#  {'birthday': Timestamp('1996-08-11 00:00:00'),
#   'overall_rating': 61,
#   'player_fifa_api_id': 220876,
#   'player_name': 'F. Honorat',
#   'player_positions': 'ST',
#   'potential': 71,
#   'similarity_score': 0.14102904738992444}]

# %% [markdown]
# ## Use Case 3: Best-Search: Get the best player of all similar players

# %% [markdown]
# After getting the top K most similar players, which players are the best players out of them?

# %% [markdown]
# Using the earlier example (use case 2), we notice that each player has a "potential" field. Let's sort them by their potential

# %%
sorted(response, key=lambda response: response['potential'], reverse=True)
# Out:
# [{'player_name': 'Munir',
#   'player_positions': 'RW, LW, ST',
#   'overall_rating': 73,
#   'potential': 85,
#   'birthday': Timestamp('1995-09-01 00:00:00'),
#   'player_fifa_api_id': 220253,
#   'similarity_score': 0.24818256723712764},
#  {'player_name': 'B. Traoré',
#   'player_positions': 'ST, RW',
#   'overall_rating': 74,
#   'potential': 85,
#   'birthday': Timestamp('1995-09-06 00:00:00'),
#   'player_fifa_api_id': 207948,
#   'similarity_score': 0.14100624228455244},
#  {'player_name': 'T. Werner',
#   'player_positions': 'LM, ST',
#   'overall_rating': 72,
#   'potential': 84,
#   'birthday': Timestamp('1996-03-06 00:00:00'),
#   'player_fifa_api_id': 212188,
#   'similarity_score': 0.1495583463483166},
#  {'player_name': 'P. Roberts',
#   'player_positions': 'RM',
#   'overall_rating': 65,
#   'potential': 81,
#   'birthday': Timestamp('1997-02-05 00:00:00'),
#   'player_fifa_api_id': 221982,
#   'similarity_score': 0.13519795426862563},
#  {'player_name': 'M. Simon',
#   'player_positions': 'ST',
#   'overall_rating': 70,
#   'potential': 80,
#   'birthday': Timestamp('1995-07-12 00:00:00'),
#   'player_fifa_api_id': 216820,
#   'similarity_score': 0.14247333998658931},
#  {'player_name': 'J. Murillo',
#   'player_positions': 'LW, RW',
#   'overall_rating': 67,
#   'potential': 80,
#   'birthday': Timestamp('1995-11-21 00:00:00'),
#   'player_fifa_api_id': 228738,
#   'similarity_score': 0.13427267452677916},
#  {'player_name': 'K. Coman',
#   'player_positions': 'ST, LW',
#   'overall_rating': 69,
#   'potential': 79,
#   'birthday': Timestamp('1996-06-13 00:00:00'),
#   'player_fifa_api_id': 213345,
#   'similarity_score': 0.17972101983643746},
#  {'player_name': 'T. Dierckx',
#   'player_positions': 'RW',
#   'overall_rating': 68,
#   'potential': 78,
#   'birthday': Timestamp('1995-05-09 00:00:00'),
#   'player_fifa_api_id': 216295,
#   'similarity_score': 0.1583054079533606},
#  {'player_name': 'B. Finne',
#   'player_positions': 'ST, LM, RM',
#   'overall_rating': 67,
#   'potential': 78,
#   'birthday': Timestamp('1995-02-13 00:00:00'),
#   'player_fifa_api_id': 209264,
#   'similarity_score': 0.15493891660110376},
#  {'player_name': 'J. Augustin',
#   'player_positions': 'RW',
#   'overall_rating': 69,
#   'potential': 78,
#   'birthday': Timestamp('1997-06-16 00:00:00'),
#   'player_fifa_api_id': 225713,
#   'similarity_score': 0.1382665258388682},
#  {'player_name': 'João Vigário',
#   'player_positions': 'RW',
#   'overall_rating': 69,
#   'potential': 77,
#   'birthday': Timestamp('1995-11-20 00:00:00'),
#   'player_fifa_api_id': 229147,
#   'similarity_score': 0.16666375271275863}]

# %% [markdown]
# We can do the same for Use Case 1, but lets sort by ability instead. We are finding the best player most similar to Messi.

# %%
all_index = Service_Index(embeddings, embeddings_columns)
response = all_index.search_by_player_name('L. Messi')

# %%
sorted(response, key=lambda response: response['potential'], reverse=True)
# Out:
# [{'player_name': 'A. Robben',
#   'player_positions': 'RM, LM, RW',
#   'overall_rating': 90,
#   'potential': 90,
#   'birthday': Timestamp('1984-01-23 00:00:00'),
#   'player_fifa_api_id': 9014,
#   'similarity_score': 0.3158182371135131},
#  {'player_name': 'P. Dybala',
#   'player_positions': 'ST',
#   'overall_rating': 78,
#   'potential': 88,
#   'birthday': Timestamp('1993-11-15 00:00:00'),
#   'player_fifa_api_id': 211110,
#   'similarity_score': 0.576062518992101},
#  {'player_name': 'M. Özil',
#   'player_positions': 'CAM, LW',
#   'overall_rating': 87,
#   'potential': 88,
#   'birthday': Timestamp('1988-10-15 00:00:00'),
#   'player_fifa_api_id': 176635,
#   'similarity_score': 0.3395830491197915},
#  {'player_name': 'N. Fékir',
#   'player_positions': 'ST, CAM, RW, LW',
#   'overall_rating': 79,
#   'potential': 85,
#   'birthday': Timestamp('1993-07-18 00:00:00'),
#   'player_fifa_api_id': 216594,
#   'similarity_score': 0.2593831580882039},
#  {'player_name': 'Munir',
#   'player_positions': 'RW, LW, ST',
#   'overall_rating': 73,
#   'potential': 85,
#   'birthday': Timestamp('1995-09-01 00:00:00'),
#   'player_fifa_api_id': 220253,
#   'similarity_score': 0.24818256723712764},
#  {'player_name': 'G. dos Santos',
#   'player_positions': 'ST, CF, LW, RW',
#   'overall_rating': 79,
#   'potential': 82,
#   'birthday': Timestamp('1989-05-11 00:00:00'),
#   'player_fifa_api_id': 170369,
#   'similarity_score': 0.2579137946576974},
#  {'player_name': 'G. Rossi',
#   'player_positions': 'ST',
#   'overall_rating': 80,
#   'potential': 80,
#   'birthday': Timestamp('1987-02-01 00:00:00'),
#   'player_fifa_api_id': 162409,
#   'similarity_score': 0.5864794747935401},
#  {'player_name': 'Z. Tošić',
#   'player_positions': 'RM',
#   'overall_rating': 80,
#   'potential': 80,
#   'birthday': Timestamp('1987-04-28 00:00:00'),
#   'player_fifa_api_id': 105454,
#   'similarity_score': 0.257114345247907},
#  {'player_name': 'A. Assiri',
#   'player_positions': 'RM, LM, LW, RW',
#   'overall_rating': 70,
#   'potential': 80,
#   'birthday': Timestamp('1994-02-26 00:00:00'),
#   'player_fifa_api_id': 213007,
#   'similarity_score': 0.255058382487601},
#  {'player_name': 'M. Fernández',
#   'player_positions': 'RM, ST',
#   'overall_rating': 69,
#   'potential': 69,
#   'birthday': Timestamp('1986-01-16 00:00:00'),
#   'player_fifa_api_id': 196871,
#   'similarity_score': 0.28410515057362185}]
